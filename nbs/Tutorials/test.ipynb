# %%
import numpy as np
from sdc.s1 import load_s1_rtc

# %%
ds = load_s1_rtc(vec='test.geojson')
ds.vh
# Out:
# <xarray.DataArray 'vh' (time: 425, y: 184, x: 235)>
# dask.array<where, shape=(425, 184, 235), dtype=float32, chunksize=(425, 184, 235), chunktype=numpy.ndarray>
# Coordinates: (12/27)
#   * time                       (time) datetime64[ns] 2018-01-03T16:30:28.5318...
#     id                         (time) <U25 'S25E031_2018_01_03_0220E0' ... 'S...
#   * x                          (x) float64 31.05 31.05 31.05 ... 31.1 31.1 31.1
#   * y                          (y) float64 -24.86 -24.86 -24.86 ... -24.9 -24.9
#     start_datetime             (time) <U27 '2018-01-03T16:30:28.531898Z' ... ...
#     end_datetime               (time) <U27 '2018-01-03T16:31:18.531291Z' ... ...
#     ...                         ...
#     sar:instrument_mode        <U2 'IW'
#     proj:shape                 object {5000}
#     proj:transform             object {0.0, -24.0, -0.0002, 0.0002, 31.0}
#     epsg                       int64 4326
#     band                       <U4 'mask'
# ...

# %%
vh_db = 10*np.log10(ds.vh.sel(time='2022-06-26', method='nearest'))
vh_db.plot(robust=True, cmap='gray')
# Out:
# /home/du23yow/micromamba/envs/sdc_env/lib/python3.11/site-packages/dask/core.py:127: RuntimeWarning: divide by zero encountered in log10
#   return func(*(_execute_task(a, cache) for a in args))
