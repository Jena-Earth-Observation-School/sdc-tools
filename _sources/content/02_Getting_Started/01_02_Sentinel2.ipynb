# %% [markdown]
# # Sentinel-2 L2A

# %% [markdown]
# ## Product description
#
# The Sentinel-2 L2A data product available in the SALDi Data Cube (SDC) is a
# mirror of [Digital Earth Africa](https://www.digitalearthafrica.org/)'s product
# of the same name. Detailed information can be found [here](https://registry.opendata.aws/deafrica-sentinel-2/).

# %% [markdown]
# ## Loading and exploring

# %%
from sdc.load import load_product

ds = load_product(product="s2_l2a", vec="site06", time_range=("2020-04-01", "2020-06-01"))
ds
# Out:
# <xarray.Dataset>
# Dimensions:                       (time: 65, y: 5501, x: 6500)
# Coordinates: (12/27)
#   * time                          (time) datetime64[ns] 2020-04-01T08:16:57 ....
#     id                            (time) <U24 'S2B_36JTT_20200401_0_L2A' ... ...
#   * x                             (x) float64 30.75 30.75 30.75 ... 32.05 32.05
#   * y                             (y) float64 -24.9 -24.9 -24.9 ... -26.0 -26.0
#     sentinel:data_coverage        (time) object 68.95 99.05 ... 95.27 67.88
#     eo:cloud_cover                (time) object 48.76 92.43 84.26 ... 0.07 0 0.7
#     ...                            ...
#     data_coverage                 (time) object None None 76.09 ... 95.27 None
#     updated                       (time) object None None ... None
#     epsg                          int64 4326
#     band                          <U3 'SCL'
#     proj:shape                    object {5490}
# ...

# %% [markdown]
# Let's have a closer look at one of the bands (`Data variable` in Xarray terminology):

# %%
ds.B04
# Out:
# <xarray.DataArray 'B04' (time: 65, y: 5501, x: 6500)>
# dask.array<astype, shape=(65, 5501, 6500), dtype=float32, chunksize=(65, 1191, 1407), chunktype=numpy.ndarray>
# Coordinates: (12/27)
#   * time                          (time) datetime64[ns] 2020-04-01T08:16:57 ....
#     id                            (time) <U24 'S2B_36JTT_20200401_0_L2A' ... ...
#   * x                             (x) float64 30.75 30.75 30.75 ... 32.05 32.05
#   * y                             (y) float64 -24.9 -24.9 -24.9 ... -26.0 -26.0
#     sentinel:data_coverage        (time) object 68.95 99.05 ... 95.27 67.88
#     eo:cloud_cover                (time) object 48.76 92.43 84.26 ... 0.07 0 0.7
#     ...                            ...
#     data_coverage                 (time) object None None 76.09 ... 95.27 None
#     updated                       (time) object None None ... None
#     epsg                          int64 4326
#     band                          <U3 'SCL'
# ...
