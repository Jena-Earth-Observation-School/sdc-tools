# %% [markdown]
# # Sentinel-1 RTC

# %% [markdown]
# ## Product description
#
# The Sentinel-1 Radiometric Terrain Corrected (RTC) data product available in the
# SALDi Data Cube (SDC) is a mirror of [Digital Earth Africa](https://www.digitalearthafrica.org/)'s
# product of the same name. Detailed information can be found [here](https://registry.opendata.aws/deafrica-sentinel-1/).

# %% [markdown]
# ## Loading and exploring

# %%
from sdc.load import load_product

ds = load_product(product="s1_rtc", vec="site06", time_range=("2020-04-01", "2020-06-01"))
ds
# Out:
# <xarray.Dataset>
# Dimensions:                    (time: 80, y: 5501, x: 6250)
# Coordinates: (12/26)
#   * time                       (time) datetime64[ns] 2020-04-03T16:38:45.3439...
#     id                         (time) <U25 'S26E030_2020_04_03_03B107' ... 'S...
#   * x                          (x) float64 30.75 30.75 30.75 ... 32.0 32.0 32.0
#   * y                          (y) float64 -24.9 -24.9 -24.9 ... -26.0 -26.0
#     odc:region_code            (time) <U7 'S26E030' 'S25E030' ... 'S26E031'
#     constellation              <U10 'sentinel-1'
#     ...                         ...
#     start_datetime             (time) <U27 '2020-04-03T16:38:45.343959Z' ... ...
#     sat:absolute_orbit         (time) int64 31965 21003 21003 ... 21805 21805
#     proj:shape                 object {5000}
#     epsg                       int64 4326
#     band                       <U4 'mask'
#     description                <U9 'data mask'
# Data variables:
#     vv                         (time, y, x) float32 dask.array<chunksize=(80, 794, 938), meta=np.ndarray>
#     vh                         (time, y, x) float32 dask.array<chunksize=(80, 794, 938), meta=np.ndarray>
#     area                       (time, y, x) float32 dask.array<chunksize=(80, 794, 938), meta=np.ndarray>
#     angle                      (time, y, x) float32 dask.array<chunksize=(80, 794, 938), meta=np.ndarray>
# Attributes:
#     spec:        RasterSpec(epsg=4326, bounds=(30.75, -26.0, 32.0500000000000...
#     crs:         epsg:4326
#     transform:   | 0.00, 0.00, 30.75|\n| 0.00,-0.00,-24.90|\n| 0.00, 0.00, 1.00|
#     resolution:  0.0002

# %% [markdown]
# Let's have a closer look at one of the bands (`Data variable` in Xarray terminology):

# %%
ds.vh
# Out:
# <xarray.DataArray 'vh' (time: 80, y: 5501, x: 6250)>
# dask.array<where, shape=(80, 5501, 6250), dtype=float32, chunksize=(80, 794, 938), chunktype=numpy.ndarray>
# Coordinates: (12/26)
#   * time                       (time) datetime64[ns] 2020-04-03T16:38:45.3439...
#     id                         (time) <U25 'S26E030_2020_04_03_03B107' ... 'S...
#   * x                          (x) float64 30.75 30.75 30.75 ... 32.0 32.0 32.0
#   * y                          (y) float64 -24.9 -24.9 -24.9 ... -26.0 -26.0
#     odc:region_code            (time) <U7 'S26E030' 'S25E030' ... 'S26E031'
#     constellation              <U10 'sentinel-1'
#     ...                         ...
#     start_datetime             (time) <U27 '2020-04-03T16:38:45.343959Z' ... ...
#     sat:absolute_orbit         (time) int64 31965 21003 21003 ... 21805 21805
#     proj:shape                 object {5000}
#     epsg                       int64 4326
#     band                       <U4 'mask'
#     description                <U9 'data mask'
# Attributes:
#     polarization:  ['VH']
#     description:   polarization VH
