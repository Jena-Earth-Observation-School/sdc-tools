# %% [markdown]
# # Sentinel-1 RTC

# %%
from sdc.s1 import load_s1_rtc

ds = load_s1_rtc(vec="../../_assets/test.geojson", time_range=("2020-01-01", "2021-01-01"))
ds
# Out:
# <xarray.Dataset>
# Dimensions:                    (time: 89, y: 184, x: 235)
# Coordinates: (12/27)
#   * time                       (time) datetime64[ns] 2020-01-01T03:18:28.5135...
#     id                         (time) <U25 'S25E031_2020_01_01_038179' ... 'S...
#   * x                          (x) float64 31.05 31.05 31.05 ... 31.1 31.1 31.1
#   * y                          (y) float64 -24.86 -24.86 -24.86 ... -24.9 -24.9
#     sat:absolute_orbit         (time) int64 30601 30667 19705 ... 35851 35917
#     sar:frequency_band         <U1 'C'
#     ...                         ...
#     sar:polarizations          object {'VH', 'VV'}
#     proj:transform             object {0.0, -24.0, -0.0002, 0.0002, 31.0}
#     proj:shape                 object {5000}
#     epsg                       int64 4326
#     band                       <U4 'mask'
#     description                <U9 'data mask'
# Data variables:
# ...

# %%
ds.vh
# Out:
# <xarray.DataArray 'vh' (time: 89, y: 184, x: 235)>
# dask.array<where, shape=(89, 184, 235), dtype=float32, chunksize=(89, 184, 235), chunktype=numpy.ndarray>
# Coordinates: (12/27)
#   * time                       (time) datetime64[ns] 2020-01-01T03:18:28.5135...
#     id                         (time) <U25 'S25E031_2020_01_01_038179' ... 'S...
#   * x                          (x) float64 31.05 31.05 31.05 ... 31.1 31.1 31.1
#   * y                          (y) float64 -24.86 -24.86 -24.86 ... -24.9 -24.9
#     sat:absolute_orbit         (time) int64 30601 30667 19705 ... 35851 35917
#     sar:frequency_band         <U1 'C'
#     ...                         ...
#     sar:polarizations          object {'VH', 'VV'}
#     proj:transform             object {0.0, -24.0, -0.0002, 0.0002, 31.0}
#     proj:shape                 object {5000}
#     epsg                       int64 4326
#     band                       <U4 'mask'
#     description                <U9 'data mask'
# Attributes:
# ...
